# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/home/mplitt','2P_scratch')
mouse = 'GRABDA6'

file_list = ({'date': '08_12_2020', 'scene':'SingleMorph','session':1,'scan':5},
             {'date': '10_12_2020', 'scene':'NeuroMods_Days2to5','session':2,'scan':1},
             {'date': '12_12_2020', 'scene':'NeuroMods_LocationA','session':8,'scan':6},
             {'date': '13_12_2020', 'scene':'NeuroMods_Day6Image','session':2,'scan':9},
             {'date': '14_12_2020', 'scene':'NeuroMods_LocationB','session':3,'scan':3},
             {'date': '15_12_2020', 'scene':'NeuroMods_Day8Image','session':1,'scan':2},
             {'date': '16_12_2020', 'scene':'NeuroMods_LocationA','session':3,'scan':2},
             {'date': '17_12_2020', 'scene':'NM_MorphBlocks','session':1,'scan':2},
             {'date': '19_12_2020', 'scene':'NM_RandomMorphs','session':2,'scan':3},
             {'date': '21_12_2020', 'scene':'NM_RandomMorphs','session':4,'scan':6},
             {'date': '22_12_2020', 'scene':'NM_Morph1ToDreamLand','session':1,'scan':2},
             {'date': '24_12_2020', 'scene':'NM_Morph1ToDreamLand','session':2,'scan':2},
             {'date': '26_12_2020', 'scene':'NM_DreamLandToPizzaLand','session':1,'scan':3},
             {'date': '28_12_2020', 'scene':'NM_PizzaLandOnly','session':2,'scan':5})

# %%
for f in file_list:
    
    scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
    
    
    try:
        source_folder  = os.path.join('/media/mplitt','Backup Plus')
        source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
        info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
    except:
        source_folder  = os.path.join('/media/mplitt','Backup Plus1','2P_Data')
        source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
        info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
    print(info['max_idx'])
# Out:
# 25848
# 17949
# 20790
# 22886
# 18028
# 21699
# 15052
# 25892
# 20625
# 21457
# 23101
# 21327
# 24947
# 20380

# %%
for f in file_list:
    
    scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
    
    
    try:
        source_folder  = os.path.join('/media/mplitt','Backup Plus')
        source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
        info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
    except:
        source_folder  = os.path.join('/media/mplitt','Backup Plus1','2P_Data')
        source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
        info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
            
    file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
    h5path = os.path.join(file_stem,scan_str+".h5")
#     if not os.path.exists(h5path):
#         _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)
    print(h5path,os.path.split(h5path)[0])
    ops = TwoPUtils.s2p.set_ops(d={'data_path': [os.path.split(h5path)[0]],
                                   'save_path0': file_stem,
                                   'fast_disk':[],
                                   'move_bin':True,
                                   'two_step_registration':True,
                                   'maxregshiftNR':10,
                                   'nchannels':2,
                                   'tau':.7,
                                   'functional_chan':2,
                                   'nimg_init': 2000,
                                   'fs':info['frame_rate'],
                                   'roidetect':True,
                                   'input_format':"h5",
                                   'h5py_key':'data',
                                   'sparse_mode':True,
                                   'threshold_scaling':1.,
                                   'nchannels':2})
    ops=s2p.run_s2p(ops=ops)

#     os.remove(h5path)
# Out:
# /home/mplitt/2P_scratch/GRABDA6/08_12_2020/SingleMorph/SingleMorph_001_005/SingleMorph_001_005.h5 /home/mplitt/2P_scratch/GRABDA6/08_12_2020/SingleMorph/SingleMorph_001_005
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/08_12_2020/SingleMorph/SingleMorph_001_005/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2295,498,766], 59.80 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.91, threshold 19.12
# 0 ROIs, score=180.56
# Found 934 ROIs, 67.75 sec
# After removing overlaps, 908 ROIs remain
# Masks made in 17.48 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 168.02 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 908 ROIs in 25848 frames, 70.90 sec.
# Extracted fluorescence from 908 ROIs in 25848 frames, 70.94 sec.
# added enhanced mean image
# ----------- Total 155.85 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.04 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.31 sec.
# Plane 0 processed in 325.37 sec (can open in GUI).
# total = 326.88 sec.
# TOTAL RUNTIME 326.88 sec
# /home/mplitt/2P_scratch/GRABDA6/10_12_2020/NeuroMods_Days2to5/NeuroMods_Days2to5_002_001/NeuroMods_Days2to5_002_001.h5 /home/mplitt/2P_scratch/GRABDA6/10_12_2020/NeuroMods_Days2to5/NeuroMods_Days2to5_002_001
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/10_12_2020/NeuroMods_Days2to5/NeuroMods_Days2to5_002_001/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1574,416,694], 36.39 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.31, threshold 13.12
# 0 ROIs, score=131.39
# Found 952 ROIs, 33.54 sec
# After removing overlaps, 933 ROIs remain
# Masks made in 16.32 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 107.65 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 933 ROIs in 17949 frames, 60.09 sec.
# Extracted fluorescence from 933 ROIs in 17949 frames, 59.95 sec.
# added enhanced mean image
# ----------- Total 135.13 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.13 sec.
# Plane 0 processed in 244.07 sec (can open in GUI).
# total = 245.40 sec.
# TOTAL RUNTIME 245.40 sec
# /home/mplitt/2P_scratch/GRABDA6/12_12_2020/NeuroMods_LocationA/NeuroMods_LocationA_008_006/NeuroMods_LocationA_008_006.h5 /home/mplitt/2P_scratch/GRABDA6/12_12_2020/NeuroMods_LocationA/NeuroMods_LocationA_008_006
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/12_12_2020/NeuroMods_LocationA/NeuroMods_LocationA_008_006/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1829,416,694], 46.03 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.52, threshold 15.24
# 0 ROIs, score=130.03
# Found 686 ROIs, 40.24 sec
# After removing overlaps, 682 ROIs remain
# Masks made in 9.93 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 110.46 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 682 ROIs in 20790 frames, 59.72 sec.
# Extracted fluorescence from 682 ROIs in 20790 frames, 59.29 sec.
# added enhanced mean image
# ----------- Total 133.72 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.92 sec.
# Plane 0 processed in 245.22 sec (can open in GUI).
# total = 246.58 sec.
# TOTAL RUNTIME 246.58 sec
# /home/mplitt/2P_scratch/GRABDA6/13_12_2020/NeuroMods_Day6Image/NeuroMods_Day6Image_002_009/NeuroMods_Day6Image_002_009.h5 /home/mplitt/2P_scratch/GRABDA6/13_12_2020/NeuroMods_Day6Image/NeuroMods_Day6Image_002_009
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/13_12_2020/NeuroMods_Day6Image/NeuroMods_Day6Image_002_009/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1959,416,694], 51.65 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.63, threshold 16.32
# 0 ROIs, score=149.86
# Found 613 ROIs, 39.76 sec
# After removing overlaps, 609 ROIs remain
# Masks made in 10.49 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 115.59 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 609 ROIs in 22886 frames, 65.91 sec.
# Extracted fluorescence from 609 ROIs in 22886 frames, 72.76 sec.
# added enhanced mean image
# ----------- Total 154.57 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.79 sec.
# Plane 0 processed in 271.06 sec (can open in GUI).
# total = 272.47 sec.
# TOTAL RUNTIME 272.47 sec
# /home/mplitt/2P_scratch/GRABDA6/14_12_2020/NeuroMods_LocationB/NeuroMods_LocationB_003_003/NeuroMods_LocationB_003_003.h5 /home/mplitt/2P_scratch/GRABDA6/14_12_2020/NeuroMods_LocationB/NeuroMods_LocationB_003_003
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/14_12_2020/NeuroMods_LocationB/NeuroMods_LocationB_003_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1557,416,694], 43.57 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.30, threshold 12.98
# 0 ROIs, score=123.74
# Found 487 ROIs, 33.17 sec
# After removing overlaps, 486 ROIs remain
# Masks made in 8.53 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 97.42 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 486 ROIs in 18028 frames, 53.40 sec.
# Extracted fluorescence from 486 ROIs in 18028 frames, 53.58 sec.
# added enhanced mean image
# ----------- Total 122.36 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.57 sec.
# Plane 0 processed in 220.43 sec (can open in GUI).
# total = 221.83 sec.
# TOTAL RUNTIME 221.83 sec
# /home/mplitt/2P_scratch/GRABDA6/15_12_2020/NeuroMods_Day8Image/NeuroMods_Day8Image_001_002/NeuroMods_Day8Image_001_002.h5 /home/mplitt/2P_scratch/GRABDA6/15_12_2020/NeuroMods_Day8Image/NeuroMods_Day8Image_001_002
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/15_12_2020/NeuroMods_Day8Image/NeuroMods_Day8Image_001_002/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1885,416,694], 54.46 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.57, threshold 15.71
# 0 ROIs, score=154.55
# Found 445 ROIs, 38.91 sec
# After removing overlaps, 444 ROIs remain
# Masks made in 7.90 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 111.67 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 444 ROIs in 21699 frames, 61.29 sec.
# Extracted fluorescence from 444 ROIs in 21699 frames, 61.83 sec.
# added enhanced mean image
# ----------- Total 138.30 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.04 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.66 sec.
# Plane 0 processed in 250.75 sec (can open in GUI).
# total = 252.28 sec.
# TOTAL RUNTIME 252.29 sec
# /home/mplitt/2P_scratch/GRABDA6/16_12_2020/NeuroMods_LocationA/NeuroMods_LocationA_003_002/NeuroMods_LocationA_003_002.h5 /home/mplitt/2P_scratch/GRABDA6/16_12_2020/NeuroMods_LocationA/NeuroMods_LocationA_003_002
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/16_12_2020/NeuroMods_LocationA/NeuroMods_LocationA_003_002/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1313,416,694], 37.80 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.09, threshold 10.94
# 0 ROIs, score=103.74
# Found 496 ROIs, 28.21 sec
# After removing overlaps, 491 ROIs remain
# Masks made in 8.41 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 86.19 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 491 ROIs in 15052 frames, 45.07 sec.
# Extracted fluorescence from 491 ROIs in 15052 frames, 44.67 sec.
# added enhanced mean image
# ----------- Total 105.20 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.46 sec.
# Plane 0 processed in 191.93 sec (can open in GUI).
# total = 193.37 sec.
# TOTAL RUNTIME 193.37 sec
# /home/mplitt/2P_scratch/GRABDA6/17_12_2020/NM_MorphBlocks/NM_MorphBlocks_001_002/NM_MorphBlocks_001_002.h5 /home/mplitt/2P_scratch/GRABDA6/17_12_2020/NM_MorphBlocks/NM_MorphBlocks_001_002
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/17_12_2020/NM_MorphBlocks/NM_MorphBlocks_001_002/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2241,416,694], 63.98 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.87, threshold 18.68
# 0 ROIs, score=177.57
# Found 407 ROIs, 46.25 sec
# After removing overlaps, 405 ROIs remain
# Masks made in 6.63 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 127.08 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 405 ROIs in 25892 frames, 69.96 sec.
# Extracted fluorescence from 405 ROIs in 25892 frames, 70.42 sec.
# added enhanced mean image
# ----------- Total 155.45 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.61 sec.
# Plane 0 processed in 283.23 sec (can open in GUI).
# total = 284.73 sec.
# TOTAL RUNTIME 284.73 sec
# /home/mplitt/2P_scratch/GRABDA6/19_12_2020/NM_RandomMorphs/NM_RandomMorphs_002_003/NM_RandomMorphs_002_003.h5 /home/mplitt/2P_scratch/GRABDA6/19_12_2020/NM_RandomMorphs/NM_RandomMorphs_002_003
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/19_12_2020/NM_RandomMorphs/NM_RandomMorphs_002_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1784,416,694], 52.67 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.49, threshold 14.87
# 0 ROIs, score=131.13
# Found 378 ROIs, 34.29 sec
# After removing overlaps, 378 ROIs remain
# Masks made in 5.84 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 101.67 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 378 ROIs in 20625 frames, 49.81 sec.
# Extracted fluorescence from 378 ROIs in 20625 frames, 47.79 sec.
# added enhanced mean image
# ----------- Total 111.65 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.42 sec.
# Plane 0 processed in 213.85 sec (can open in GUI).
# total = 215.22 sec.
# TOTAL RUNTIME 215.22 sec
# /home/mplitt/2P_scratch/GRABDA6/21_12_2020/NM_RandomMorphs/NM_RandomMorphs_004_006/NM_RandomMorphs_004_006.h5 /home/mplitt/2P_scratch/GRABDA6/21_12_2020/NM_RandomMorphs/NM_RandomMorphs_004_006
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/21_12_2020/NM_RandomMorphs/NM_RandomMorphs_004_006/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1821,416,694], 50.79 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.52, threshold 15.18
# 0 ROIs, score=184.19
# Found 631 ROIs, 36.04 sec
# After removing overlaps, 621 ROIs remain
# Masks made in 10.19 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 111.74 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 621 ROIs in 21457 frames, 68.39 sec.
# Extracted fluorescence from 621 ROIs in 21457 frames, 58.30 sec.
# added enhanced mean image
# ----------- Total 140.77 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.10 sec.
# Plane 0 processed in 253.78 sec (can open in GUI).
# total = 255.15 sec.
# TOTAL RUNTIME 255.15 sec
# /home/mplitt/2P_scratch/GRABDA6/22_12_2020/NM_Morph1ToDreamLand/NM_Morph1ToDreamLand_001_002/NM_Morph1ToDreamLand_001_002.h5 /home/mplitt/2P_scratch/GRABDA6/22_12_2020/NM_Morph1ToDreamLand/NM_Morph1ToDreamLand_001_002
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/22_12_2020/NM_Morph1ToDreamLand/NM_Morph1ToDreamLand_001_002/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1991,416,694], 56.85 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.66, threshold 16.59
# 0 ROIs, score=188.70
# Found 544 ROIs, 43.31 sec
# After removing overlaps, 538 ROIs remain
# Masks made in 9.37 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 122.64 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 538 ROIs in 23101 frames, 69.02 sec.
# Extracted fluorescence from 538 ROIs in 23101 frames, 69.08 sec.
# added enhanced mean image
# ----------- Total 153.38 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.85 sec.
# Plane 0 processed in 277.01 sec (can open in GUI).
# total = 278.31 sec.
# TOTAL RUNTIME 278.31 sec
# /home/mplitt/2P_scratch/GRABDA6/24_12_2020/NM_Morph1ToDreamLand/NM_Morph1ToDreamLand_002_002/NM_Morph1ToDreamLand_002_002.h5 /home/mplitt/2P_scratch/GRABDA6/24_12_2020/NM_Morph1ToDreamLand/NM_Morph1ToDreamLand_002_002
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/24_12_2020/NM_Morph1ToDreamLand/NM_Morph1ToDreamLand_002_002/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1824,416,694], 50.69 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.52, threshold 15.20
# 0 ROIs, score=154.92
# Found 708 ROIs, 43.40 sec
# After removing overlaps, 697 ROIs remain
# Masks made in 12.71 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 123.69 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 697 ROIs in 21327 frames, 53.76 sec.
# Extracted fluorescence from 697 ROIs in 21327 frames, 52.62 sec.
# added enhanced mean image
# ----------- Total 120.21 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.88 sec.
# Plane 0 processed in 244.90 sec (can open in GUI).
# total = 246.28 sec.
# TOTAL RUNTIME 246.28 sec
# /home/mplitt/2P_scratch/GRABDA6/26_12_2020/NM_DreamLandToPizzaLand/NM_DreamLandToPizzaLand_001_003/NM_DreamLandToPizzaLand_001_003.h5 /home/mplitt/2P_scratch/GRABDA6/26_12_2020/NM_DreamLandToPizzaLand/NM_DreamLandToPizzaLand_001_003
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/26_12_2020/NM_DreamLandToPizzaLand/NM_DreamLandToPizzaLand_001_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2116,416,694], 55.30 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.76, threshold 17.63
# 0 ROIs, score=216.21
# Found 692 ROIs, 41.93 sec
# After removing overlaps, 681 ROIs remain
# Masks made in 12.26 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 125.46 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 681 ROIs in 24947 frames, 67.74 sec.
# Extracted fluorescence from 681 ROIs in 24947 frames, 65.33 sec.
# added enhanced mean image
# ----------- Total 146.70 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.95 sec.
# Plane 0 processed in 273.24 sec (can open in GUI).
# total = 274.55 sec.
# TOTAL RUNTIME 274.55 sec
# /home/mplitt/2P_scratch/GRABDA6/28_12_2020/NM_PizzaLandOnly/NM_PizzaLandOnly_002_005/NM_PizzaLandOnly_002_005.h5 /home/mplitt/2P_scratch/GRABDA6/28_12_2020/NM_PizzaLandOnly/NM_PizzaLandOnly_002_005
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/GRABDA6/28_12_2020/NM_PizzaLandOnly/NM_PizzaLandOnly_002_005/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 20380 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 117.31 sec.
# Registered 2000/20380 in 71.54s
# Registered 4000/20380 in 144.84s
# Registered 6000/20380 in 218.11s
# Registered 8000/20380 in 289.25s
# Registered 10000/20380 in 360.37s
# Registered 12000/20380 in 431.73s
# Registered 14000/20380 in 503.37s
# Registered 16000/20380 in 574.55s
# Registered 18000/20380 in 645.94s
# Registered 20000/20380 in 717.18s
# Registered second channel in 131.55 sec.
# ----------- Total 1014.61 sec
# Registration metrics, 24.25 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1721,416,694], 42.26 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.43, threshold 14.34
# 0 ROIs, score=161.68
# Found 676 ROIs, 32.83 sec
# After removing overlaps, 663 ROIs remain
# Masks made in 11.57 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 102.34 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 663 ROIs in 20380 frames, 64.40 sec.
# Extracted fluorescence from 663 ROIs in 20380 frames, 66.83 sec.
# added enhanced mean image
# ----------- Total 147.47 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.23 sec.
# Plane 0 processed in 1290.68 sec (can open in GUI).
# total = 1291.55 sec.
# TOTAL RUNTIME 1291.55 sec

# %%
for f in file_list:
    
    scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
    
    # !rsync -rltP mplitt@dtn.sherlock.stanford.edu:/oak/stanford/groups/giocomo/InVivoDA/2P_Data/{mouse}/{f['date']}/{f['scene']}/{scan_str}/suite2p /mnt/BigDisk/2P_scratch/{mouse}/{f['date']}/{f['scene']}/{scan_str}
    
    
#     try:
#         source_folder  = os.path.join('/media/mplitt','Backup Plus')
#         source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
#         info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
#     except:
#         source_folder  = os.path.join('/media/mplitt','Backup Plus1','2P_Data')
#         source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
#         info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
            
#     file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
#     h5path = os.path.join(file_stem,scan_str+".h5")
# Out:
# Password:
# rsync error: received SIGINT, SIGTERM, or SIGHUP (code 20) at rsync.c(644) [Receiver=3.1.3]
# Password:
# rsync error: received SIGINT, SIGTERM, or SIGHUP (code 20) at rsync.c(644) [Receiver=3.1.3]
# Password:
# rsync error: received SIGINT, SIGTERM, or SIGHUP (code 20) at rsync.c(644) [Receiver=3.1.3]
# Password:
